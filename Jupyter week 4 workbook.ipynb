# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: D. Scientist**
#
# Senior Scientist

# %% [markdown]
# *I am interested in data science because I am looking to change careers. I know it is a big field and I am interested in learning more about it.*

# %% [markdown]
# ### In Cell 5 my code is supposed to display a simple output, mine will be to multiply 8 by 7.

# %%
(8*7)
# Out:
# 56

# %% [markdown]
# ---
# * This cell
# * has a bulleted list
# ~~done~~
# ---
# 1. here is the third criteria
# 1. a numbered list
# 1. done
# ---
